# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /Users/vicki/anaconda3/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: torchvision in /Users/vicki/anaconda3/lib/python3.11/site-packages (0.16.1)
# Requirement already satisfied: torchaudio in /Users/vicki/anaconda3/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: filelock in /Users/vicki/anaconda3/lib/python3.11/site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in /Users/vicki/anaconda3/lib/python3.11/site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /Users/vicki/anaconda3/lib/python3.11/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /Users/vicki/anaconda3/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /Users/vicki/anaconda3/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /Users/vicki/anaconda3/lib/python3.11/site-packages (from torch) (2023.4.0)
# Requirement already satisfied: numpy in /Users/vicki/anaconda3/lib/python3.11/site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in /Users/vicki/anaconda3/lib/python3.11/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/vicki/anaconda3/lib/python3.11/site-packages (from torchvision) (10.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vicki/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vicki/anaconda3/lib/python3.11/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vicki/anaconda3/lib/python3.11/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vicki/anaconda3/lib/python3.11/site-packages (from requests->torchvision) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vicki/anaconda3/lib/python3.11/site-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /Users/vicki/anaconda3/lib/python3.11/site-packages (from sympy->torch) (1.3.0)

# %%
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 21695, done.
# remote: Counting objects: 100% (947/947), done.
# remote: Compressing objects: 100% (526/526), done.
# remote: Total 21695 (delta 624), reused 618 (delta 420), pack-reused 20748
# Receiving objects: 100% (21695/21695), 11.59 MiB | 12.37 MiB/s, done.
# Resolving deltas: 100% (15285/15285), done.

# %%
# !cd yolov5
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
from ultralytics import YOLO

# %%
#model = torch.hub.load('ultralytics/ultralytics', 'yolov5s')
model = YOLO("yolov8n.pt")
# Out:
# Using cache found in /Users/vicki/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-10-28 Python-3.11.5 torch-2.1.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %% [markdown]
# ## 3. Image Object Detection

# %%
img = 'https://ultralytics.com/images/zidane.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 1247.8ms pre-process, 198.1ms inference, 1.6ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.xyxy
# Out:
# [tensor([[7.42975e+02, 4.83955e+01, 1.14184e+03, 7.20000e+02, 8.81053e-01, 0.00000e+00],
#          [4.42008e+02, 4.37522e+02, 4.96654e+02, 7.09974e+02, 6.75214e-01, 2.70000e+01],
#          [1.23024e+02, 1.93287e+02, 7.15662e+02, 7.19724e+02, 6.65812e-01, 0.00000e+00],
#          [9.82803e+02, 3.08417e+02, 1.02737e+03, 4.19987e+02, 2.60076e-01, 2.70000e+01]])]

# %% [markdown]
# ## 4. Real-Time Object Detection

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)

# %% [markdown]
# ## 5. Training from Scratch

# %%
import uuid
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images')
labels = ['attentive', 'drowsy', 'looking away']
number_imgs = 33

# %%
cap = cv2.VideoCapture(0)
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    for img_num in range(1,number_imgs+1):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        ret, frame = cap.read()
        
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        cv2.imwrite(imgname, frame)
        cv2.imshow('Image Collection', frame)
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# Collecting images for attentive
# Collecting images for attentive, image number 1
# Collecting images for attentive, image number 2
# Collecting images for attentive, image number 3
# Collecting images for attentive, image number 4
# Collecting images for attentive, image number 5
# Collecting images for attentive, image number 6
# Collecting images for attentive, image number 7
# Collecting images for attentive, image number 8
# Collecting images for attentive, image number 9
# Collecting images for attentive, image number 10
# Collecting images for attentive, image number 11
# Collecting images for attentive, image number 12
# Collecting images for attentive, image number 13
# Collecting images for attentive, image number 14
# Collecting images for attentive, image number 15
# Collecting images for attentive, image number 16
# Collecting images for attentive, image number 17
# Collecting images for attentive, image number 18
# Collecting images for attentive, image number 19
# Collecting images for attentive, image number 20
# Collecting images for attentive, image number 21
# Collecting images for attentive, image number 22
# Collecting images for attentive, image number 23
# Collecting images for attentive, image number 24
# Collecting images for attentive, image number 25
# Collecting images for attentive, image number 26
# Collecting images for attentive, image number 27
# Collecting images for attentive, image number 28
# Collecting images for attentive, image number 29
# Collecting images for attentive, image number 30
# Collecting images for attentive, image number 31
# Collecting images for attentive, image number 32
# Collecting images for attentive, image number 33
# Collecting images for drowsy
# Collecting images for drowsy, image number 1
# Collecting images for drowsy, image number 2
# Collecting images for drowsy, image number 3
# Collecting images for drowsy, image number 4
# Collecting images for drowsy, image number 5
# Collecting images for drowsy, image number 6
# Collecting images for drowsy, image number 7
# Collecting images for drowsy, image number 8
# Collecting images for drowsy, image number 9
# Collecting images for drowsy, image number 10
# Collecting images for drowsy, image number 11
# Collecting images for drowsy, image number 12
# Collecting images for drowsy, image number 13
# Collecting images for drowsy, image number 14
# Collecting images for drowsy, image number 15
# Collecting images for drowsy, image number 16
# Collecting images for drowsy, image number 17
# Collecting images for drowsy, image number 18
# Collecting images for drowsy, image number 19
# Collecting images for drowsy, image number 20
# Collecting images for drowsy, image number 21
# Collecting images for drowsy, image number 22
# Collecting images for drowsy, image number 23
# Collecting images for drowsy, image number 24
# Collecting images for drowsy, image number 25
# Collecting images for drowsy, image number 26
# Collecting images for drowsy, image number 27
# Collecting images for drowsy, image number 28
# Collecting images for drowsy, image number 29
# Collecting images for drowsy, image number 30
# Collecting images for drowsy, image number 31
# Collecting images for drowsy, image number 32
# Collecting images for drowsy, image number 33
# Collecting images for looking away
# Collecting images for looking away, image number 1
# Collecting images for looking away, image number 2
# Collecting images for looking away, image number 3
# Collecting images for looking away, image number 4
# Collecting images for looking away, image number 5
# Collecting images for looking away, image number 6
# Collecting images for looking away, image number 7
# Collecting images for looking away, image number 8
# Collecting images for looking away, image number 9
# Collecting images for looking away, image number 10
# Collecting images for looking away, image number 11
# Collecting images for looking away, image number 12
# Collecting images for looking away, image number 13
# Collecting images for looking away, image number 14
# Collecting images for looking away, image number 15
# Collecting images for looking away, image number 16
# Collecting images for looking away, image number 17
# Collecting images for looking away, image number 18
# Collecting images for looking away, image number 19
# Collecting images for looking away, image number 20
# Collecting images for looking away, image number 21
# Collecting images for looking away, image number 22
# Collecting images for looking away, image number 23
# Collecting images for looking away, image number 24
# Collecting images for looking away, image number 25
# Collecting images for looking away, image number 26
# Collecting images for looking away, image number 27
# Collecting images for looking away, image number 28
# Collecting images for looking away, image number 29
# Collecting images for looking away, image number 30
# Collecting images for looking away, image number 31
# Collecting images for looking away, image number 32
# Collecting images for looking away, image number 33
# -1

# %%
# !git clone https://github.com/HumanSignal/labelImg
# Out:
# Cloning into 'labelImg'...
# remote: Enumerating objects: 2097, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 2097 (delta 0), reused 4 (delta 0), pack-reused 2090
# Receiving objects: 100% (2097/2097), 237.14 MiB | 17.21 MiB/s, done.
# Resolving deltas: 100% (1242/1242), done.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Collecting pyqt5
#   Obtaining dependency information for pyqt5 from https://files.pythonhosted.org/packages/f2/8a/aa7699436ed898a1cc34724bbb672a879ea51b8067f0ab71843d52f6fcd0/PyQt5-5.15.10-cp37-abi3-macosx_10_13_x86_64.whl.metadata
#   Downloading PyQt5-5.15.10-cp37-abi3-macosx_10_13_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: lxml in /Users/vicki/anaconda3/lib/python3.11/site-packages (4.9.3)
# Collecting PyQt5-sip<13,>=12.13 (from pyqt5)
#   Obtaining dependency information for PyQt5-sip<13,>=12.13 from https://files.pythonhosted.org/packages/bc/de/fff654a38821e42beb914ecca72c4ac0ae3dab1f94666ae8015a152a197f/PyQt5_sip-12.13.0-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading PyQt5_sip-12.13.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (504 bytes)
# Collecting PyQt5-Qt5>=5.15.2 (from pyqt5)
#   Obtaining dependency information for PyQt5-Qt5>=5.15.2 from https://files.pythonhosted.org/packages/66/f5/0a684b2b33b1f1dceaf894d4e8a105f523bb08003f81c89a91e509c5f854/PyQt5_Qt5-5.15.11-py3-none-macosx_10_13_x86_64.whl.metadata
#   Downloading PyQt5_Qt5-5.15.11-py3-none-macosx_10_13_x86_64.whl.metadata (536 bytes)
# Downloading PyQt5-5.15.10-cp37-abi3-macosx_10_13_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 15.0 MB/s eta 0:00:0000:0100:01
# Downloading PyQt5_Qt5-5.15.11-py3-none-macosx_10_13_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 13.6 MB/s eta 0:00:0000:0100:01
# Downloading PyQt5_sip-12.13.0-cp311-cp311-macosx_10_9_universal2.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, pyqt5
#   Attempting uninstall: PyQt5-sip
#     Found existing installation: PyQt5-sip 12.11.0
#     Uninstalling PyQt5-sip-12.11.0:
#       Successfully uninstalled PyQt5-sip-12.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.4.3 requires pyqtwebengine<5.16, which is not installed.
# Successfully installed PyQt5-Qt5-5.15.11 PyQt5-sip-12.13.0 pyqt5-5.15.10
# Traceback (most recent call last):
#   File "/Users/vicki/anaconda3/bin/pyrcc5", line 5, in <module>
#     from PyQt5.pyrcc_main import main
#   File "/Users/vicki/anaconda3/lib/python3.11/site-packages/PyQt5/pyrcc_main.py", line 21, in <module>
#     from PyQt5.QtCore import PYQT_VERSION_STR, QDir, QFile
# ImportError: dlopen(/Users/vicki/anaconda3/lib/python3.11/site-packages/PyQt5/QtCore.abi3.so, 0x0002): Library not loaded: '@rpath/QtCore.framework/Versions/5/QtCore'
#   Referenced from: '/Users/vicki/anaconda3/lib/python3.11/site-packages/PyQt5/QtCore.abi3.so'
#   Reason: tried: '/Users/vicki/anaconda3/lib/python3.11/site-packages/PyQt5/Qt5/lib/QtCore.framework/Versions/5/QtCore' (no such file), '/Users/vicki/anaconda3/lib/python3.11/site-packages/PyQt5/Qt5/lib/QtCore.framework/Versions/5/QtCore' (no such file), '/Users/vicki/anaconda3/bin/../lib/QtCore.framework/Versions/5/QtCore' (no such file), '/Users/vicki/anaconda3/bin/../lib/QtCore.framework/Versions/5/QtCore' (no such file), '/Library/Frameworks/QtCore.framework/Versions/5/QtCore' (no such file), '/System/Library/Frameworks/QtCore.framework/Versions/5/QtCore' (no such file)

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 175 --data dataset.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=175, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.11.5 torch-2.1.0 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=18
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     62031  models.yolo.Detect                      [18, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7068175 parameters, 7068175 gradients, 16.1 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning /Users/vicki/aiproj/iceeu/data/labels.cache... 159 images, 0 bac
# val: Scanning /Users/vicki/aiproj/iceeu/data/labels.cache... 159 images, 0 backg
#
# AutoAnchor: 5.65 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp4/labels.jpg...
# Image sizes 320 train, 320 val
# Using 4 dataloader workers
# Logging results to runs/train/exp4
# Starting training for 175 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/174         0G     0.1181    0.01483     0.0774         27        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159   0.000551     0.0566   0.000314   7.65e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/174         0G    0.09041     0.0235    0.07124         32        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159    0.00352      0.338    0.00282    0.00068
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/174         0G    0.07651    0.02625    0.06288         30        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159      0.163      0.455      0.221     0.0636
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/174         0G    0.06916    0.02748    0.05264         38        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159     0.0467      0.416     0.0607     0.0198
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/174         0G     0.0673    0.02658    0.04617         34        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     166/174         0G   0.009444      0.005   0.004688         36        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159      0.999          1      0.995      0.977
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     167/174         0G   0.009382   0.005292   0.005116         27        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159      0.999          1      0.995      0.978
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     168/174         0G   0.009397   0.004534   0.003778         25        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159      0.999          1      0.995      0.978
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     169/174         0G   0.008635    0.00464   0.003903         33        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159      0.999          1      0.995      0.978
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     170/174         0G   0.009075   0.004719   0.004118         28        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159      0.999          1      0.995       0.98
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     171/174         0G   0.009467   0.004702   0.003746         36        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159      0.999          1      0.995      0.978
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     172/174         0G   0.008599   0.004782   0.004097         30        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159      0.999          1      0.995      0.981
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     173/174         0G   0.009061   0.005003   0.003571         30        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159      0.998          1      0.995      0.982
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     174/174         0G   0.008684   0.005195   0.004609         31        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159      0.998          1      0.995      0.982
#
# 175 epochs completed in 7.258 hours.
# Optimizer stripped from runs/train/exp4/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp4/weights/best.pt, 14.4MB
#
# Validating runs/train/exp4/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all        159        159      0.998          1      0.995      0.982
#                  awake        159         53      0.998          1      0.995      0.993
#                 drowsy        159         51      0.999          1      0.995      0.983
#           looking away        159         55      0.998          1      0.995      0.969
# Results saved to runs/train/exp4

# %% [markdown]
# ## 6. Loading the model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp4/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /Users/vicki/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-11-17 Python-3.11.5 torch-2.1.0 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read()
    
    # Make detections
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
# # Full Code:

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

model = torch.hub.load('ultralytics/yolov5', 'custom', \
                       path='yolov5/runs/train/exp4/weights/last.pt', \
                       force_reload=True)

cap = cv2.VideoCapture(1)
while True:
    ret, frame = cap.read()
    
    # Make detections
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /Users/vicki/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-12-4 Python-3.11.5 torch-2.1.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...
# -1
